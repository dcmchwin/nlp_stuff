# %%
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
X = np.random.rand(1000, 2)
y = np.zeros(X.shape[0])
y[X[:, 1] > 0.5] = 1

plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)
# Out:
# c:\users\dcm\documents\git\training\nlp_stuff\venv_nlp\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
model = Sequential()
model.add(Dense(64, input_dim=2,  activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train,
          batch_size=10,
          epochs=10,
          validation_data=(X_test, y_test))
# Out:
# Train on 700 samples, validate on 300 samples
# Epoch 1/10
# 700/700 [==============================] - 0s 677us/step - loss: 0.5886 - acc: 0.8529 - val_loss: 0.4711 - val_acc: 0.8900
# Epoch 2/10
# 700/700 [==============================] - 0s 150us/step - loss: 0.3475 - acc: 0.9100 - val_loss: 0.2420 - val_acc: 0.9300
# Epoch 3/10
# 700/700 [==============================] - 0s 140us/step - loss: 0.1894 - acc: 0.9371 - val_loss: 0.1591 - val_acc: 0.9533
# Epoch 4/10
# 700/700 [==============================] - 0s 191us/step - loss: 0.1237 - acc: 0.9671 - val_loss: 0.1153 - val_acc: 0.9733
# Epoch 5/10
# 700/700 [==============================] - 0s 176us/step - loss: 0.0960 - acc: 0.9814 - val_loss: 0.0897 - val_acc: 0.9933
# Epoch 6/10
# 700/700 [==============================] - 0s 157us/step - loss: 0.0802 - acc: 0.9800 - val_loss: 0.0765 - val_acc: 0.9933
# Epoch 7/10
# 700/700 [==============================] - 0s 181us/step - loss: 0.0753 - acc: 0.9771 - val_loss: 0.0745 - val_acc: 0.9733
# Epoch 8/10
# 700/700 [==============================] - 0s 139us/step - loss: 0.0681 - acc: 0.9786 - val_loss: 0.0612 - val_acc: 0.9967
# Epoch 9/10
# 700/700 [==============================] - 0s 144us/step - loss: 0.0590 - acc: 0.9929 - val_loss: 0.0599 - val_acc: 0.9900
# Epoch 10/10
# 700/700 [==============================] - 0s 140us/step - loss: 0.0550 - acc: 0.9900 - val_loss: 0.0514 - val_acc: 1.0000
